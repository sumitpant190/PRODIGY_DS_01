# %% [markdown]
# # Import required libraries.

# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Reading csv file

# %%
data = pd.read_csv("C:/Users/sumit/OneDrive/Desktop/World-population-by-countries-dataset.csv")
data = data.dropna()
data.head()
# Out:
#                   Country Name Country Code         1960         1961  \
# 0                        Aruba          ABW      54208.0      55434.0
# 1  Africa Eastern and Southern          AFE  130836765.0  134159786.0
# 2                  Afghanistan          AFG    8996967.0    9169406.0
# 3   Africa Western and Central          AFW   96396419.0   98407221.0
# 4                       Angola          AGO    5454938.0    5531451.0
#
#           1962         1963         1964         1965         1966  \
# 0      56234.0      56699.0      57029.0      57357.0      57702.0
# 1  137614644.0  141202036.0  144920186.0  148769974.0  152752671.0
# 2    9351442.0    9543200.0    9744772.0    9956318.0   10174840.0
# 3  100506960.0  102691339.0  104953470.0  107289875.0  109701811.0
# 4    5608499.0    5679409.0    5734995.0    5770573.0    5781305.0
#
#           1967  ...         2012         2013         2014         2015  \
# 0      58044.0  ...     102565.0     103165.0     103776.0     104339.0
# 1  156876454.0  ...  547482863.0  562601578.0  578075373.0  593871847.0
# 2   10399936.0  ...   31161378.0   32269592.0   33370804.0   34413603.0
# 3  112195950.0  ...  370243017.0  380437896.0  390882979.0  401586651.0
# 4    5774440.0  ...   25107925.0   26015786.0   26941773.0   27884380.0
#
#           2016         2017         2018         2019         2020  \
# 0     104865.0     105361.0     105846.0     106310.0     106766.0
# 1  609978946.0  626392880.0  643090131.0  660046272.0  677243299.0
# 2   35383028.0   36296111.0   37171922.0   38041757.0   38928341.0
# 3  412551299.0  423769930.0  435229381.0  446911598.0  458803476.0
# 4   28842482.0   29816769.0   30809787.0   31825299.0   32866268.0
#
#           2021
# 0     107195.0
# 1  694665117.0
# 2   39835428.0
# 3  470898870.0
# 4   33933611.0
#
# [5 rows x 64 columns]

# %%
data.tail()
# Out:
#      Country Name Country Code        1960        1961        1962  \
# 261        Kosovo          XKX    947000.0    966000.0    994000.0
# 262   Yemen, Rep.          YEM   5315351.0   5393034.0   5473671.0
# 263  South Africa          ZAF  17099836.0  17524533.0  17965733.0
# 264        Zambia          ZMB   3070780.0   3164330.0   3260645.0
# 265      Zimbabwe          ZWE   3776679.0   3905038.0   4039209.0
#
#            1963        1964        1965        1966        1967  ...  \
# 261   1022000.0   1050000.0   1078000.0   1106000.0   1135000.0  ...
# 262   5556767.0   5641598.0   5727745.0   5816241.0   5907873.0  ...
# 263  18423157.0  18896303.0  19384838.0  19888259.0  20406863.0  ...
# 264   3360099.0   3463211.0   3570466.0   3681953.0   3797877.0  ...
# 265   4178726.0   4322854.0   4471178.0   4623340.0   4779825.0  ...
#
#            2012        2013        2014        2015        2016        2017  \
# 261   1807106.0   1818117.0   1812771.0   1788196.0   1777557.0   1791003.0
# 262  24473176.0  25147112.0  25823488.0  26497881.0  27168210.0  27834811.0
# 263  52832659.0  53687125.0  54544184.0  55386369.0  56207649.0  57009751.0
# 264  14465148.0  14926551.0  15399793.0  15879370.0  16363449.0  16853608.0
# 265  13115149.0  13350378.0  13586710.0  13814642.0  14030338.0  14236599.0
#
#            2018        2019        2020        2021
# 261   1797085.0   1788878.0   1790133.0   1806279.0
# 262  28498683.0  29161922.0  29825968.0  30490639.0
# 263  57792520.0  58558267.0  59308690.0  60041996.0
# 264  17351714.0  17861034.0  18383956.0  18920657.0
# 265  14438812.0  14645473.0  14862927.0  15092171.0
#
# [5 rows x 64 columns]

# %%
data.keys()
# Out:
# Index(['Country Name', 'Country Code', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021'],
#       dtype='object')

# %%
data.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.620000e+02  2.620000e+02  2.620000e+02  2.620000e+02  2.620000e+02
# mean   1.181073e+08  1.196648e+08  1.217890e+08  1.244281e+08  1.270884e+08
# std    3.708464e+08  3.752044e+08  3.817404e+08  3.902524e+08  3.988079e+08
# min    2.833000e+03  3.077000e+03  3.367000e+03  3.703000e+03  4.063000e+03
# 25%    5.149835e+05  5.257388e+05  5.372568e+05  5.462485e+05  5.555595e+05
# 50%    3.821420e+06  3.923497e+06  4.029190e+06  4.138240e+06  4.215254e+06
# 75%    2.654210e+07  2.731494e+07  2.810353e+07  2.897732e+07  2.988023e+07
# max    3.032156e+09  3.071596e+09  3.124561e+09  3.189656e+09  3.255146e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.620000e+02  2.620000e+02  2.620000e+02  2.620000e+02  2.620000e+02
# mean   1.298145e+08  1.326840e+08  1.355457e+08  1.384770e+08  1.415136e+08
# std    4.075981e+08  4.169476e+08  4.262349e+08  4.357762e+08  4.457073e+08
# min    4.460000e+03  4.675000e+03  4.922000e+03  5.194000e+03  5.461000e+03
# 25%    5.652400e+05  5.752960e+05  5.858988e+05  5.973332e+05  6.074150e+05
# 50%    4.269828e+06  4.362524e+06  4.437342e+06  4.496863e+06  4.587932e+06
# 75%    3.079075e+07  3.157015e+07  3.203917e+07  3.273505e+07  3.321787e+07
# max    3.322047e+09  3.392098e+09  3.461620e+09  3.532783e+09  3.606554e+09
#
#        ...          2012          2013          2014          2015  \
# count  ...  2.620000e+02  2.620000e+02  2.620000e+02  2.620000e+02
# mean   ...  2.896568e+08  2.934915e+08  2.973388e+08  3.011787e+08
# std    ...  9.048559e+08  9.160772e+08  9.272859e+08  9.384288e+08
# min    ...  1.013600e+04  1.020800e+04  1.028900e+04  1.037400e+04
# 25%    ...  1.409856e+06  1.427346e+06  1.444861e+06  1.463192e+06
# 50%    ...  9.925639e+06  1.002641e+07  1.022601e+07  1.031988e+07
# 75%    ...  6.266009e+07  6.315469e+07  6.364901e+07  6.401981e+07
# max    ...  7.089255e+09  7.175500e+09  7.261847e+09  7.347679e+09
#
#                2016          2017          2018          2019          2020  \
# count  2.620000e+02  2.620000e+02  2.620000e+02  2.620000e+02  2.620000e+02
# mean   3.050354e+08  3.089059e+08  3.126950e+08  3.164058e+08  3.200637e+08
# std    9.495885e+08  9.607996e+08  9.716794e+08  9.822635e+08  9.925641e+08
# min    1.047400e+04  1.057700e+04  1.067800e+04  1.076400e+04  1.083400e+04
# 25%    1.513734e+06  1.568308e+06  1.626351e+06  1.678092e+06  1.723720e+06
# 50%    1.044287e+07  1.055377e+07  1.062854e+07  1.069673e+07  1.069921e+07
# 75%    6.436557e+07  6.467832e+07  6.495070e+07  6.505952e+07  6.524430e+07
# max    7.433651e+09  7.519371e+09  7.602716e+09  7.683806e+09  7.763933e+09
#
#                2021
# count  2.620000e+02
# mean   3.235051e+08
# std    1.002263e+09
# min    1.087300e+04
# 25%    1.762791e+06
# 50%    1.068401e+07
# 75%    6.586954e+07
# max    7.836631e+09
#
# [8 rows x 62 columns]

# %%
data[['Country Name','2021']]
# Out:
#                     Country Name         2021
# 0                          Aruba     107195.0
# 1    Africa Eastern and Southern  694665117.0
# 2                    Afghanistan   39835428.0
# 3     Africa Western and Central  470898870.0
# 4                         Angola   33933611.0
# ..                           ...          ...
# 261                       Kosovo    1806279.0
# 262                  Yemen, Rep.   30490639.0
# 263                 South Africa   60041996.0
# 264                       Zambia   18920657.0
# 265                     Zimbabwe   15092171.0
#
# [262 rows x 2 columns]

# %% [markdown]
# Plotting bar chart for 'Population of Specific Countries in 2021."

# %% [markdown]
# # Population of Specific Countries in 2021

# %%
countries = ['South Africa','Zimbabwe','Aruba','Afghanistan','India','China','Brazil','Sri Lanka','Russia','Turkey','Japan']
filter_data = data[data['Country Name'].isin(countries)]
plt.figure(figsize=(15, 6))
plt.title("Population of Specific Countries in 2021")
sns.barplot(x='Country Name', y='2021', data=filter_data)
plt.ylabel("Population")
plt.xlabel("Countries")
plt.show()

# %% [markdown]
# # Distribution of 2021 Population with KDE by Country

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data=filter_data, x="2021", kde=True, hue="Country Name", element="step")

plt.title("Distribution of 2004 Population with KDE by Country")
plt.xlabel("Population in 2021")
plt.ylabel("Frequency")

plt.legend(title="Country")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
filter_data.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  9.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00
# mean   1.469795e+08  1.476783e+08  1.497844e+08  1.531814e+08  1.565602e+08
# std    2.418505e+08  2.413255e+08  2.441222e+08  2.499091e+08  2.555931e+08
# min    5.420800e+04  5.543400e+04  5.623400e+04  5.669900e+04  5.702900e+04
# 25%    8.996967e+06  9.169406e+06  9.351442e+06  9.543200e+06  9.744772e+06
# 50%    1.709984e+07  1.752453e+07  1.796573e+07  1.842316e+07  1.889630e+07
# 75%    9.321600e+07  9.405500e+07  9.493300e+07  9.590000e+07  9.690300e+07
# max    6.670700e+08  6.603300e+08  6.657700e+08  6.823350e+08  6.983550e+08
#
#                1965          1966          1967          1968          1969  \
# count  9.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00
# mean   1.600683e+08  1.639671e+08  1.677964e+08  1.717710e+08  1.759833e+08
# std    2.615294e+08  2.684064e+08  2.750389e+08  2.819390e+08  2.893251e+08
# min    5.735700e+04  5.770200e+04  5.804400e+04  5.837700e+04  5.873400e+04
# 25%    9.956318e+06  1.017484e+07  1.039994e+07  1.063706e+07  1.089377e+07
# 50%    1.938484e+07  1.988826e+07  2.040686e+07  2.094215e+07  2.149608e+07
# 75%    9.795200e+07  9.885100e+07  9.987900e+07  1.010110e+08  1.022190e+08
# max    7.151850e+08  7.354000e+08  7.545500e+08  7.745100e+08  7.960250e+08
#
#        ...          2012          2013          2014          2015  \
# count  ...  9.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00
# mean   ...  3.405026e+08  3.436176e+08  3.466538e+08  3.495905e+08
# std    ...  5.537269e+08  5.587381e+08  5.635911e+08  5.682701e+08
# min    ...  1.025650e+05  1.031650e+05  1.037760e+05  1.043390e+05
# 25%    ...  2.042500e+07  2.058500e+07  2.077800e+07  2.097000e+07
# 50%    ...  5.283266e+07  5.368712e+07  5.454418e+07  5.538637e+07
# 75%    ...  1.992873e+08  2.010359e+08  2.027637e+08  2.044718e+08
# max    ...  1.354190e+09  1.363240e+09  1.371860e+09  1.379860e+09
#
#                2016          2017          2018          2019          2020  \
# count  9.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00
# mean   3.524972e+08  3.554210e+08  3.580957e+08  3.605556e+08  3.627834e+08
# std    5.729013e+08  5.776138e+08  5.818765e+08  5.857671e+08  5.892757e+08
# min    1.048650e+05  1.053610e+05  1.058460e+05  1.063100e+05  1.067660e+05
# 25%    2.120300e+07  2.144400e+07  2.167000e+07  2.180300e+07  2.191900e+07
# 50%    5.620765e+07  5.700975e+07  5.779252e+07  5.855827e+07  5.930869e+07
# 75%    2.061631e+08  2.078338e+08  2.094693e+08  2.110495e+08  2.125594e+08
# max    1.387790e+09  1.396215e+09  1.402760e+09  1.407745e+09  1.411100e+09
#
#                2021
# count  9.000000e+00
# mean   3.647419e+08
# std    5.922963e+08
# min    1.071950e+05
# 25%    2.215600e+07
# 50%    6.004200e+07
# 75%    2.139934e+08
# max    1.412360e+09
#
# [8 rows x 62 columns]

# %%
hist=filter_data.hist(bins=4)

# %% [markdown]
# # Distribution of population with KDE by country over the years

# %%
years = ['1960', '1986', '2004', '2014', '2021']

plt.figure(figsize=(15, 6))
for year in years:
    sns.histplot(data=filter_data, x=year, kde=True, hue="Country Name", element="step")

plt.title("Distribution of Population with KDE by Country Over the Years")
plt.xlabel("Population")
plt.ylabel("Frequency")

plt.legend(title="Country")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Histogram.

# %%
data['population_change'] = data['1965'] - data['2002']

# Histogram
plt.figure(figsize=(15,6))
plt.hist(data['population_change'], bins=10, color='blue', edgecolor='black')
plt.title('Distribution of Population Change (1965-2002)')
plt.xlabel('Population Change')
plt.ylabel('Number of Countries')
plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
data['percentage_increase'] = ((data['2002'] - data['2020']) / data['2020']) * 100
top_countries = data.nlargest(5, 'percentage_increase')

# %% [markdown]
# # Population of Countries with Rapid Growth from 2015 to 2021

# %%
bar_width = 0.35
index = range(len(top_countries))

plt.figure(figsize=(15, 8))
bar1 = plt.bar(index, top_countries['2015'], bar_width, label='2015', color='b', edgecolor='black')
bar2 = plt.bar([i+bar_width for i in index], top_countries['2015'], bar_width, label='2020', color='r', edgecolor='black')

plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population of Countries with Rapid Growth from 2015 to 2020')
plt.xticks([i+bar_width/2 for i in index], top_countries['Country Name'])
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Population of Countries with Least Growth from 2000 to 2020

# %%
data['percentage_increase'] = ((data['2000'] - data['2020']) / (data['2020'] + 1e-10)) * 100

bottom_countries = data.nsmallest(8, 'percentage_increase')

bar_width = 0.35
index = range(len(bottom_countries))

plt.figure(figsize=(15, 8))
bar1 = plt.bar(index, bottom_countries['2020'], bar_width, label='2020', color='b', edgecolor='black')
bar2 = plt.bar([i+bar_width for i in index], bottom_countries['2000'], bar_width, label='2000', color='r', edgecolor='black')

plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population of Countries with Least Growth from 2000 to 2020')
plt.xticks([i+bar_width/2 for i in index], bottom_countries['Country Name'])
plt.legend()
plt.tight_layout()
plt.show()

# %%
data['population_change_2015_2021'] = data['2015'] - data['2021']

country_with_largest_dip = data.nsmallest(5, 'population_change_2015_2021')

print(country_with_largest_dip[['Country Name', 'population_change_2015_2021']])
# Out:
#             Country Name  population_change_2015_2021
# 259                World                 -488951787.0
# 140  Low & middle income                 -460038228.0
# 103     IDA & IBRD total                 -457879059.0
# 156        Middle income                 -358075553.0
# 139  Lower middle income                 -269335014.0

# %% [markdown]
# # Population of India vs China from 1960 to 2021 :

# %%
country_data_1 = data[data['Country Name'] == 'India'].iloc[0]
country_data_2 = data[data['Country Name'] == 'China'].iloc[0]

years = ['1960', '1965', '1975', '1980', '2000', '2002', '2010','2015','2021']
population_values_1 = country_data_1[years]
population_values_2 = country_data_2[years]

bar_width = 0.35
index = range(len(years))

plt.figure(figsize=(15, 8))
bars1 = plt.bar(index, population_values_1, bar_width, label='India', color='blue', edgecolor='black')
bars2 = plt.bar([i+bar_width for i in index], population_values_2, bar_width, label='China', color='red', edgecolor='black')

plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population of India vs China from 1960 to 2021')
plt.xticks([i+bar_width/2 for i in index], years)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Population Trend from 1960 to 2021:

# %%
plt.figure(figsize=(15, 8))
plt.plot(years, population_values_1, marker='o', label='India', color='blue')
plt.plot(years, population_values_2, marker='o', label='China', color='red')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population Trend from 1960 to 2021')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()
